# %% [markdown]
# <a href="https://colab.research.google.com/github/avivek5692/fmml2021/blob/main/FMML_Course_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-22 05:59:58--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   141MB/s    in 0.5s
#
# 2022-06-22 06:00:03 (141 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7418   1712.07102v1  The randomized-feature approach has been succe...  stat
# 32658   1411.2057v1  A common phenomena in modern recommendation sy...    cs
# 16825  1706.04138v2  In this work, we explore multiple neural archi...    cs
# 3574   1712.07639v1  In medicine, visualizing chromosomes is import...    cs
# 21890   1408.1336v2  This paper generalizes an important result fro...  stat
# ...             ...                                                ...   ...
# 27484  1703.08492v1  One of the challenges in Content-Based Image R...    cs
# 6186   1609.02200v2  Probabilistic models with discrete latent vari...  stat
# 25757  1511.05204v1  Facial expression is temporally dynamic event ...    cs
# 7664   1802.07028v1  Bayesian optimization (BO) is a popular techni...    cs
# 11358  1511.01644v1  We aim to produce predictive models that are n...  stat
#
#                                                    title  year  \
# 7418   On Data-Dependent Random Features for Improved...  2017
# 32658           Online Collaborative-Filtering on Graphs  2014
# 16825  An Exploration of Neural Sequence-to-Sequence ...  2017
# 3574   Image Segmentation to Distinguish Between Over...  2017
# 21890  On the Generalization of the C-Bound to Struct...  2014
# ...                                                  ...   ...
# 27484  Content-Based Image Retrieval Based on Late Fu...  2017
# 6186                   Discrete Variational Autoencoders  2016
# 25757  Learning Expressionlets via Universal Manifold...  2015
# 7664   High-Dimensional Bayesian Optimization via Add...  2018
# 11358  Interpretable classifiers using rules and Baye...  2015
#
#                                                 keywords
# 7418   [randomized, successfully, approximation, supe...
# 32658  [phenomena, recommendation, exploration, explo...
# 16825  [architectures, automatic, translation, archit...
# 3574   [visualizing, chromosomes, important, diagnost...
# 21890  [generalizes, important, literature, classific...
# ...                                                  ...
# 27484  [challenges, retrieval, represented, performan...
# 6186   [probabilistic, variables, naturally, difficul...
# 25757  [expression, temporally, decomposed, occurring...
# 7664   [optimization, technique, sequential, optimiza...
# 11358  [predictive, interpretable, statements, discre...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7418     [randomized, successfully, approximation, supe...
# 32658    [phenomena, recommendation, exploration, explo...
# 16825    [architectures, automatic, translation, archit...
# 3574     [visualizing, chromosomes, important, diagnost...
# 21890    [generalizes, important, literature, classific...
#                                ...
# 22217    [classification, optimization, classification,...
# 20203    [approaches, typically, conceived, independent...
# 19039    [variability, structure, equivalence, sufficie...
# 16165    [linguistic, classifies, languages, according,...
# 10588    [combination, classifiers, increasingly, impor...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8713 words.
# Out of those 4504 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="524ec72f-6273-4ad8-9dd0-0b2049f21548" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("524ec72f-6273-4ad8-9dd0-0b2049f21548")) {                    Plotly.newPlot(                        "524ec72f-6273-4ad8-9dd0-0b2049f21548",                        [{"x":["exploration","distribution","implemented","algorithm","dependent","empirical","approximation","randomization","introducing","processing","negligible","successfully","generalizability","generalization","randomized","promising","probability","concerned","additional","employing","supervised","performance","efficiently","benchmark","parameters","ascertain","collaborative","parametrized","tradeoffs","competitive","exploitation","structure","recommendation","filtering","demonstrate","underlying","approaches","recommendations","constrains","algorithms","conversely","presented","strategies","importantly","phenomena","technical","population","properties","unstructured","importance","translates","guarantees","advantage","perspective","expansion","translation","influence","combinations","rightarrow","available","investigate","monolingual","architecture","published","automatic","architectures","attention","incorporate","visualizing","segmentation","necessary","unfortunately","diagnostics","intersection","effective","important","biomedical","chromosome","automated","customized","distinguishing","convolutional","partially","development","overlapping","distinguish","chromosomes","multiclass","literature","relaxations","structured","generalizes","classification","expressed","statistical","multilabel","prediction","considering","aesthetics","qualitative","variation","relationships","renderings","paintings","components","introduce","encourage","additionally","combining","progression","transform","experimental","enhancement","attributes","discriminator","retaining","expression","resulting","effectiveness","perceptual","reference","introduced","impressive","representative","attribute","performing","distributions","restricting","quantifying","techniques","extraction","associated","represent","relationship","economics","landscape","decomposed","information","examination","financial","regularized","significant","economies","understanding","volatility","automatically","summarized","genuinely","movements","environmental","organized","influencing","regressions","visualization","explained","remarkable","consequently","challenges","neuroscience","correctly","cumbersome","outperforms","approximate","individual","especially","annotation","difficult","bipartite","quantitative","profoundly","microscopy","leveraging","collected","evaluated","applications","segmenting","efficient","optimization","computational","including","significantly","combinatorial","motivates","improvement","convergent","projected","counterpart","exponential","stochastic","polyhedral","answering","iteration","convergence","conditional","framework","characterizations","preservation","consequence","characterized","semantics"],"y":[66,192,106,805,54,156,121,4,53,282,8,89,7,104,32,136,155,24,114,36,205,939,163,218,252,3,31,7,6,117,22,336,24,70,565,108,400,12,9,610,3,178,103,29,25,41,55,195,26,73,7,74,85,74,18,93,57,38,1,280,146,12,264,37,171,125,170,69,9,197,76,33,7,13,245,351,14,3,100,4,10,390,53,110,25,27,2,11,133,5,108,46,535,30,149,4,222,68,5,63,50,68,2,4,123,339,13,67,95,7,80,387,35,70,26,16,44,162,223,30,64,139,22,32,31,79,104,11,8,384,142,99,104,71,5,13,9,677,6,5,41,259,1,154,0,167,6,2,18,21,15,3,2,34,20,25,30,122,13,29,4,276,127,108,129,64,140,7,75,3,13,43,66,148,410,15,401,326,289,251,282,34,9,163,11,16,17,50,139,2,53,50,117,87,562,7,6,24,30,83],"type":"bar"},{"x":["exploration","distribution","implemented","algorithm","dependent","empiric ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4504,), (4504, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8183333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Solutions</span> <span style=''>to</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>deep</span> <span style=''>learning</span> <br/><br/><span style=''>Despite</span> <span style=''>the</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successes</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>systems</span> <span style=''>there</span> <span style=''>are</span> <span style=''>concerns</span> <span style=''>about</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3137254901960783);'>limitations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discussed</span> <span style=''>most</span> <span style=''>recently</span> <span style=''>by</span> <span style=''>Gary</span> <span style=''>Marcus</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.6551724137931034);'>discusses</span> <span style=''>Marcuss</span> <span style=''>concerns</span> <span style=''>and</span> <span style=''>some</span> <span style=''>others</span> <span style=''>together</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>to</span> <span style=''>several</span> <span style=''>of</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>the</span> <span style=''>P</span> <span style=''>theory</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6952380952380952);'>intelligence</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>realisation</span> <span style=''>in</span> <span style=''>the</span> <span style=''>SP</span> <span style=''>computer</span> <span style=''>model</span> <span style=''>The</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantages</span> <span style=''>of</span> <span style=''>the</span> <span style=''>SP</span> <span style=''>system</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.40259740259740256);'>requirements</span> <span style=''>for</span> <span style=''>data</span> <span style=''>and</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>from</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.48484848484848486);'>experience</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>model</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>and</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>strengths</span> <span style=''>in</span> <span style=''>several</span> <span style=''>kinds</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6923076923076923);'>reasoning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>commonsense</span> <span style='background-color:rgba(0, 255, 0, 0.6923076923076923);'>reasoning</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714286);'>transparency</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4098360655737705);'>representation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3319919517102615);'>k ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Boosting</span> <span style=''>as</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>based</span> <span style=''>method</span> <br/><br/><span style=''>Boosting</span> <span style=''>combines</span> <span style=''>weak</span> <span style=''>(biased)</span> <span style=''>learners</span> <span style=''>to</span> <span style=''>obtain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connection</span> <span style=''>between</span> <span style=''>boosting</span> <span style=''>and</span> <span style=''>kernel</span> <span style=''>based</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>highlighting</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>In</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>ell</span> <span style=''>2</span> <span style=''>boosting</span> <span style=''>we</span> <span style=''>start</span> <span style=''>with</span> <span style=''>a</span> <span style=''>weak</span> <span style=''>linear</span> <span style=''>learner</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>K</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>boosting</span> <span style=''>with</span> <span style=''>this</span> <span style=''>learner</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>with</span> <span style=''>a</span> <span style=''>special</span> <span style=''>it</span> <span style=''>boosting</span> <span style=''>kernel</span> <span style=''>that</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>K</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>matrix</span> <span style=''>noise</span> <span style=''>variance</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>The</span> <span style=''>number</span> <span style=''>of</span> <span style=''>boosting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterations</span> <span style=''>is</span> <span style=''>modeled</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameter</span> <span style=''>and</span> <span style=''>fit</span> <span style=''>along</span> <span style=''>with</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>using</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>We</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>the</span> <span style=''>boosting</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Greedy</span> <span style=''>Block</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Coordinate</span> <span style=''>Descent</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(255, 0, 0, 0.5093555093555093);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>greedy</span> <span style=''>block</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinate</span> <span style=''>descent</span> <span style=''>(GBCD)</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>make</span> <span style=''>dense</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.5093555093555093);'>regression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>problems</span> <span style=''>GBCD</span> <span style=''>breaks</span> <span style=''>a</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>into</span> <span style=''>a</span> <span style=''>series</span> <span style=''>of</span> <span style=''>small</span> <span style=''>sub</span> <span style=''>problems</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>challenge</span> <span style=''>in</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposition</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.30136986301369856);'>identification</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>subproblem</span> <span style=''>(the</span> <span style=''>active</span> <span style=''>set</span> <span style=''>of</span> <span style=''>variables)</span> <span style=''>that</span> <span style=''>yields</span> <span style=''>the</span> <span style=''>largest</span> <span style='background-color:rgba(0, 255, 0, 0.3415637860082304);'>improvement</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3137254901960783);'>limitations</span> <span style=''>of</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>cast</span> <span style=''>the</span> <span style=''>active</span> <span style=''>set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>into</span> <span style=''>a</span> <span style=''>zero</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>that</span> <span style=''>we</span> <span style=''>solve</span> <span style=''>using</span> <span style=''>greedy</span> <span style=''>methods</span> <span style=''>By</span> <span style=''>directly</span> <span style='background-color:rgba(255, 0, 0, 0.33004926108374394);'>estimating</span> <span style=''>the</span> <span style=''>decrease</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>we</span> <span style=''>obtain</span> <span style=''>not</span> <span style=''>only</span> <span style='background ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style=''>Entropy</span> <span style=''>Search</span> <span style=''>for</span> <span style=''>Multi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Constraints</span> <br/><br/><span style=''>This</span> <span style=''>work</span> <span style=''>presents</span> <span style=''>PESMOC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style=''>Entropy</span> <span style=''>Search</span> <span style=''>for</span> <span style=''>Multi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Constraints</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>based</span> <span style=''>strategy</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>under</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>PESMOC</span> <span style=''>can</span> <span style=''>hence</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Iteratively</span> <span style=''>PESMOC</span> <span style=''>chooses</span> <span style=''>an</span> <span style=''>input</span> <span style=''>location</span> <span style=''>on</span> <span style=''>which</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximally</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>entropy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Pareto</span> <span style=''>set</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>in</span> <span style=''>PESMOC</span> <span style=''>are</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>have</span> <span style=''>similar</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>to</span> <span style=''>those</span> <span style=''>of</span> <span  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.1021215390147429)
# 	segmentation (0.07083782811938152)
# 	information (0.2434376123696512)
# 	architecture (0.09492988133764833)
# 	experimental (0.13915857605177995)
# 	representation (0.13915857605177995)
# 	detection (0.12225818051060769)
# 	different (0.2689679971233369)
# 	recognition (0.13448399856166846)
# 	convolutional (0.14023732470334413)
#
# Some Statistics words are:
# 	stochastic (0.13075780089153047)
# 	algorithm (0.37295690936106984)
# 	estimation (0.1723625557206538)
# 	variables (0.13769192669638436)
# 	statistical (0.15502724120851907)
# 	theoretical (0.1515601783060921)
# 	dimensional (0.17731550272412086)
# 	distribution (0.18375433382862805)
# 	inference (0.20208023774145617)
# 	regression (0.17979197622585438)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="365b2f2f-8253-4fe6-919d-fe2ba40edb5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("365b2f2f-8253-4fe6-919d-fe2ba40edb5a")) {                    Plotly.newPlot(                        "365b2f2f-8253-4fe6-919d-fe2ba40edb5a",                        [{"x":["exploration","distribution","implemented","algorithm","dependent","empirical","approximation","randomization","introducing","processing","negligible","successfully","generalizability","generalization","randomized","promising","probability","concerned","additional","employing","supervised","performance","efficiently","benchmark","parameters","ascertain","collaborative","parametrized","tradeoffs","competitive","exploitation","structure","recommendation","filtering","demonstrate","underlying","approaches","recommendations","constrains","algorithms","conversely","presented","strategies","importantly","phenomena","technical","population","properties","unstructured","importance","translates","guarantees","advantage","perspective","expansion","translation","influence","combinations","rightarrow","available","investigate","monolingual","architecture","published","automatic","architectures","attention","incorporate","visualizing","segmentation","necessary","unfortunately","diagnostics","intersection","effective","important","biomedical","chromosome","automated","customized","distinguishing","convolutional","partially","development","overlapping","distinguish","chromosomes","multiclass","literature","relaxations","structured","generalizes","classification","expressed","statistical","multilabel","prediction","considering","aesthetics","qualitative","variation","relationships","renderings","paintings","components","introduce","encourage","additionally","combining","progression","transform","experimental","enhancement","attributes","discriminator","retaining","expression","resulting","effectiveness","perceptual","reference","introduced","impressive","representative","attribute","performing","distributions","restricting","quantifying","techniques","extraction","associated","represent","relationship","economics","landscape","decomposed","information","examination","financial","regularized","significant","economies","understanding","volatility","automatically","summarized","genuinely","movements","environmental","organized","influencing","regressions","visualization","explained","remarkable","consequently","challenges","neuroscience","correctly","cumbersome","outperforms","approximate","individual","especially","annotation","difficult","bipartite","quantitative","profoundly","microscopy","leveraging","collected","evaluated","applications","segmenting","efficient","optimization","computational","including","significantly","combinatorial","motivates","improvement","convergent","projected","counterpart","exponential","stochastic","polyhedral","answering","iteration","convergence","conditional","framework","characterizations","preservation","consequence","characterized","semantics","interrelationships","operators","alternating","preserving","programming","preference","extensible","alternatively","implementation","preferences","characterizing","inference","observational","uncertain","benchmarks","medication","simultaneously","treatment","measurement","summarizing","autoencoders","variational","inferring","carefully","confounders","intervention","supervision","increasing","compositional","protocols","restrictions","populations","emergence","communication","developed","communicate","languages","cooperative","interpretable","naturally","constancy","probabilistic","enriching","instances","challenging","addressed","ambiguity","conjunction","detection","calibration","ambiguities","recognition","annotations","c ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	volatility
# 	medication
# 	confounders
# 	censoring
# 	dimensionalities
# 	elliptical
# 	unspecified
# 	transelliptical
# 	advocated
# 	normalising
# 	heteroscedasticity
# 	factoring
# 	adjustments
# 	graphically
# 	faithfulness
# 	distributionally
# 	eigenspace
# 	methodologically
# 	neuroscientists
# 	beforehand
# Some words which never appear in Statistics papers:
# 	ascertain
# 	chromosome
# 	chromosomes
# 	profoundly
# 	interrelationships
# 	constancy
# 	enriching
# 	occlusions
# 	downsampling
# 	curriculum
# 	comprehension
# 	coreference
# 	discourse
# 	congestion
# 	synergies
# 	recurrence
# 	dropconnect
# 	chervonenkis
# 	multitemporal
# 	enrichment

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.094633904809061e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
